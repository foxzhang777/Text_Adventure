# %% [markdown]
# ################## Check List:
# ~~~
# Strings and String Manipulation
# User-Defined Functions and Objects (variables)
# User Input and Input Handling
# Conditional and Nested Conditional Statements (if/elif/else)
# Loops (for/while)
# Controlling for Errors
#
# a game that can be successfully completed within a maximum of 4 minutes
# …a minimum of:
# (D) 3 stages (maximum of 5 stages)
# (D) 2 defined variables
# (D) 1 loop
# 1 nested conditional statement
# (D) 1 fail() function (executed whenever a user loses the game)
#
# A docstring at the beginning of game that:
# (D) Is no more than 150 words
# (D) Introduces the game and its purpose
# Identifies any bugs that are not yet worked out
#
# --------a Timer to see how fast the player wins the game!!
#
# ~~~
# * 10/16-- 3:40 AM started.
# * 8AM end. 4 hours used.
# <br>
# Reference on artist questions:<br>
# https://www.parkwestgallery.com/6-facts-you-may-not-know-about-famous-artists/

# %% [markdown]
# """
#
# Author: Runmin (Fox) Zhang
#
# DocString:
#
#     A) Introduction:
#     Welcome to Fox's <<Art or Match Race>>!!
#     That's right. Finish the race within the shortest amount of time!
#
#     Rules:
#     * In order to finish the race, the player has to survive to the final stage
#       and correctly answer the math question there.
#     * In each stage, an artist question is first prompted.
#       (The artist questions CANNOT eliminate the player)
#     * Then, the player will see the matching math questions.
#       (The math questions CAN eliminate the player, max 3 trials)
#
#     Hint:
#     * In each stage, Answer the artist question correctly to get
#       the simplest math question.
#
#     B) Known Bugs and/or Errors:
#     None.
#
# """

# %% [markdown]
# ~~~
# print("Start : %s" % time.ctime())
# time.sleep( 5 )
# print ("End : %s" % time.ctime())
# ~~~

# %%
import time
from sys import exit
from random import randint

def start_race():
    global player_name
    global player_name_upper
    global player_fav_artist


    print("Current time: %s" % time.ctime())
    print("\nFox: Greeting, player! This is the annual Art or Math Race!\n")
    print("\nFox: If you are in the right race, then \n")
    input(prompt='\n<Press Enter to continue>')
    
    print("\nFox: Great! Now please tell us your name: \n")
    player_name = input(prompt="Enter your name below:\n")
    player_name_upper = player_name.upper()
    
    print(f"""\nFox: OHHHHHHH, it's {player_name_upper} from last year! 
     I wish you the best luck this time =] \n
     And, {player_name_upper}, who is your favorite artist?""")
    player_fav_artist = input(prompt="\nEnter your fav artist below:\n")
    
    print(f"""\nFox: Ooookay! {player_name_upper} who likes {player_fav_artist}!
     The race begins now! Show us what you got!""")
    input(prompt='<Hit Enter when you are ready>\n')
    
    stage_1()

# ------------------------------------------- Stage 1 ------------------------
# ----------------------------------------------------------------------------
def stage_1():
    s1_art_choice = input(prompt = f"""\nFox: Stage 1 begins now. Please focus, {player_name_upper}!"
     Artist question of stage 1: Which artist was a serious procrastinator?
        A. Leonardo da Vinci
        B. Vincent van Gogh
        C. Claude Monet
        D. Pablo Picasso
    """)
    
    a_list = ['a','A','leonardo','Leonardo','da vinci','da Vinci',
                 'Da Vinci','Leonardo da Vinci','Leonardo Da Vinci',
                 'leonardo da vinci','LEONARDO DA VINCI']
    b_list = ['b','B','vincent','Vincent','van gogh','van Gogh',
                 'Van Gogh','Vincent van Gogh','Vincent Van Gogh',
                 'vincent van gogh','VINCENT VAN GOGH']
    c_list = ['c','C','claude','Claude','CLAUDE','monet','Monet','MONET',
                 'claude monet','Claude Monet','CLAUDE MONET']
    d_list = ['d','D','pablo','Pablo','PABLO','picasso','Picasso',
                 'PICASSO','pablo picasso','Pablo Picasso', 'PABLO PICASSO']
    
    if s1_art_choice in a_list:
        print(f"""Fox: Wow, {player_name_upper}! You know him don't you?! 
         The answer is CORRECT! 
         You can check out the explanation later.
         Now enjoy your easy math question~""")
        stage_1_easy_math()
        
    elif s1_art_choice in b_list:
        print(f"""Fox: Interesting guess, {player_name_upper}, but WRONG. 
         You can check out the explanation later.
         Now enjoy your hard math question~""")
        stage_1_hard_math()
        
    elif s1_art_choice in c_list:
        print(f"""Fox: Sorry, {player_name_upper}, you got it WRONG. 
         Monet actually painted more than 2500 paintings in his lifetime.
         You can check out the explanation later.
         Now enjoy your hard math question~""")
        stage_1_hard_math()
        
    elif s1_art_choice in d_list:
        print(f"""Fox: You picked the totally opposite guy, {player_name_upper}.
         The answer is WRONG. Picasso made more than 50000 paintings.
         A serious procrastinator cannot achieve that.
         You can check out the explanation later.
         Now enjoy your hard math question~""")
        stage_1_hard_math()
        
    else:
        print(f"""Fox: {player_name_upper}!!! Are you trying to mess with the system?
         The system does not recognize your answer.
         Please hit Enter to retry this stage.""")
        input(prompt='<Hit Enter to retry>\n')
        stage_1()
              
def stage_1_easy_math():
    chances = 3
    while chances >= 1:
        s1_answer = int(input(prompt="""Fox: Math question of stage 1: What is 1+1?\n 
        Input an integer:"""))
        if s1_answer == 2:
            print("Fox: CORRECT! You survived stage 1. Now to stage 2!")
            stage_2()

        else:
            chances -=1
            print(f"Fox: Wrong answer!!!! You have {chances} chances left.")
    eliminate()

def stage_1_hard_math():
    chances = 3
    while chances >= 1:
        s1_answer = int(input(prompt="""Fox: Math question of stage 1: What is 98+97?\n 
        Input an integer:"""))
        if s1_answer == 195:
            print("Fox: CORRECT! You survived stage 1. Now to stage 2!")
            stage_2()

        else:
            chances -=1
            print(f"Fox: Wrong answer!!!! You have {chances} chances left.")
    eliminate()
    
    
# ------------------------------------------- Stage 2 ------------------------
# ----------------------------------------------------------------------------
def stage_2():
    s2_art_choice = input(prompt = f"""\nFox: Stage 2 begins now. Please focus, {player_name_upper}!"
     Artist question of stage 2: Which artist was a serious procrastinator?
        A. Leonardo da Vinci
        B. Vincent van Gogh
        C. Claude Monet
        D. Pablo Picasso
    """)
    
    a_list = ['a','A','leonardo','Leonardo','da vinci','da Vinci',
                 'Da Vinci','Leonardo da Vinci','Leonardo Da Vinci',
                 'leonardo da vinci','LEONARDO DA VINCI']
    b_list = ['b','B','vincent','Vincent','van gogh','van Gogh',
                 'Van Gogh','Vincent van Gogh','Vincent Van Gogh',
                 'vincent van gogh','VINCENT VAN GOGH']
    c_list = ['c','C','claude','Claude','CLAUDE','monet','Monet','MONET',
                 'claude monet','Claude Monet','CLAUDE MONET']
    d_list = ['d','D','pablo','Pablo','PABLO','picasso','Picasso',
                 'PICASSO','pablo picasso','Pablo Picasso', 'PABLO PICASSO']
    
    if s2_art_choice in a_list:
        print(f"""Fox: Wow, {player_name_upper}! You know him don't you?! 
         The answer is CORRECT! 
         You can check out the explanation later.
         Now enjoy your easy math question~""")
        stage_2_easy_math()
        
    elif s2_art_choice in b_list:
        print(f"""Fox: Interesting guess, {player_name_upper}, but WRONG. 
         You can check out the explanation later.
         Now enjoy your hard math question~""")
        stage_2_hard_math()
        
    elif s2_art_choice in c_list:
        print(f"""Fox: Sorry, {player_name_upper}, you got it WRONG. 
         Monet actually painted more than 2500 paintings in his lifetime.
         You can check out the explanation later.
         Now enjoy your hard math question~""")
        stage_2_hard_math()
        
    elif s2_art_choice in d_list:
        print(f"""Fox: You picked the totally opposite guy, {player_name_upper}.
         The answer is WRONG. Picasso made more than 50000 paintings.
         A serious procrastinator cannot achieve that.
         You can check out the explanation later.
         Now enjoy your hard math question~""")
        stage_2_hard_math()
        
    else:
        print(f"""Fox: {player_name_upper}!!! Are you trying to mess with the system?
         The system does not recognize your answer.
         Please hit Enter to retry this stage.""")
        input(prompt='<Hit Enter to retry>\n')
        stage_2()
        
def stage_2_easy_math():
    chances = 3
    while chances >= 1:
        s1_answer = int(input(prompt="""Fox: Math question of stage 2: What is 1+1?\n 
        Input an integer:"""))
        if s1_answer == 2:
            print("Fox: CORRECT! You survived stage 2. Now to stage 3!")
            stage_3()

        else:
            chances -=1
            print(f"Fox: Wrong answer!!!! You have {chances} chances left.")
    eliminate()
    
def stage_2_hard_math():
    chances = 3
    while chances >= 1:
        s1_answer = int(input(prompt="""Fox: Math question of stage 2: What is 98+97?\n 
        Input an integer:"""))
        if s1_answer == 195:
            print("Fox: CORRECT! You survived stage 2. Now to stage 3!")
            stage_3()

        else:
            chances -=1
            print(f"Fox: Wrong answer!!!! You have {chances} chances left.")
    eliminate()
    
    

# ------------------------------------------- Stage 3 ------------------------
# ----------------------------------------------------------------------------
def stage_3():
    s3_art_choice = input(prompt = f"""\nFox: Stage 3 begins now. Please focus, {player_name_upper}!"
     Artist question of stage 1: Which artist was a serious procrastinator?
        A. Leonardo da Vinci
        B. Vincent van Gogh
        C. Claude Monet
        D. Pablo Picasso
    """)
    
    a_list = ['a','A','leonardo','Leonardo','da vinci','da Vinci',
                 'Da Vinci','Leonardo da Vinci','Leonardo Da Vinci',
                 'leonardo da vinci','LEONARDO DA VINCI']
    b_list = ['b','B','vincent','Vincent','van gogh','van Gogh',
                 'Van Gogh','Vincent van Gogh','Vincent Van Gogh',
                 'vincent van gogh','VINCENT VAN GOGH']
    c_list = ['c','C','claude','Claude','CLAUDE','monet','Monet','MONET',
                 'claude monet','Claude Monet','CLAUDE MONET']
    d_list = ['d','D','pablo','Pablo','PABLO','picasso','Picasso',
                 'PICASSO','pablo picasso','Pablo Picasso', 'PABLO PICASSO']
    
    if s3_art_choice in a_list:
        print(f"""Fox: Wow, {player_name_upper}! You know him don't you?! 
         The answer is CORRECT! 
         You can check out the explanation later.
         Now enjoy your easy math question~""")
        stage_3_easy_math()
        
    elif s3_art_choice in b_list:
        print(f"""Fox: Interesting guess, {player_name_upper}, but WRONG. 
         You can check out the explanation later.
         Now enjoy your hard math question~""")
        stage_3_hard_math()
        
    elif s3_art_choice in c_list:
        print(f"""Fox: Sorry, {player_name_upper}, you got it WRONG. 
         Monet actually painted more than 2500 paintings in his lifetime.
         You can check out the explanation later.
         Now enjoy your hard math question~""")
        stage_3_hard_math()
        
    elif s3_art_choice in d_list:
        print(f"""Fox: You picked the totally opposite guy, {player_name_upper}.
         The answer is WRONG. Picasso made more than 50000 paintings.
         A serious procrastinator cannot achieve that.
         You can check out the explanation later.
         Now enjoy your hard math question~""")
        stage_3_hard_math()
    
    else:
        print(f"""Fox: {player_name_upper}!!! Are you trying to mess with the system?
         The system does not recognize your answer.
         Please hit Enter to retry this stage.""")
        input(prompt='<Hit Enter to retry>\n')
        stage_3()
        
def stage_3_easy_math():
    chances = 3
    while chances >= 1:
        s1_answer = int(input(prompt="""Fox: Math question of stage 3: What is 1+1?\n 
        Input an integer:"""))
        if s1_answer == 2:
            print("Fox: CORRECT! You survived stage 3. ??????????!")
            stage_final()

        else:
            chances -=1
            print(f"Fox: Wrong answer!!!! You have {chances} chances left.")
    eliminate()
    
def stage_3_hard_math():
    chances = 3
    while chances >= 1:
        s1_answer = int(input(prompt="""Fox: Math question of stage 3: What is 98+97?\n 
        Input an integer:"""))
        if s1_answer == 195:
            print("Fox: CORRECT! You survived stage 3.?????????!")
            stage_final()

        else:
            chances -=1
            print(f"Fox: Wrong answer!!!! You have {chances} chances left.")
    eliminate()
    
# -------------------------------- final stage -------------------------------
# ----------------------------------------------------------------------------    
def stage_final():
    print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
    
    
    
# ---------------------------- fail/eliminate function -----------------------
# ----------------------------------------------------------------------------
def eliminate():
    print(f"""
Fox: Oh, I'm sorry, {player_name_upper}, looks like you've lost the race.
           
""")
    
    print(f"Fox: Would you like to play again? (Yes/No)")
    replay = input(prompt="Enter yes or no: ")
    replay = replay.lower()
    
    if replay == 'yes':
        stage_1()
        
    else:
        print(f"Fox: Thanks for racing, {player_name_upper}!")
        exit(0)

        
# ------------------------------ Start the whole game ------------------------
# ----------------------------------------------------------------------------
start_race()
# Out:
# Current time: Thu Jul  8 03:29:55 2021
#
# Fox: Greeting, player! This is the annual Art or Math Race!
#
#
# Fox: If you are in the right race, then

# %% [markdown]
# Artist Questions Recap:
#
# Q1: Which artist was a serious procrastinator?
# Answer: A. Leonardo da Vinci
# Explanation:
# Da Vinci was easily distracted. It took him 17 years to finish 2 of his most famous paintings. In his lifetime,
# Da Vinci made less than 50 drawings where as van Gogh did 900, Monet did 2500 and Picasso did more than 50000!
#
# Q2: Which artist was a serious procrastinator?
# Answer: A. Leonardo da Vinci
# Explanation:
#
# Q3: Which artist was a serious procrastinator?
# Answer: A. Leonardo da Vinci
# Explanation:
